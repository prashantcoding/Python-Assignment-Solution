# %%
#que-1)Q1. Write a program that takes your full name as input and displays the abbreviations of the first and middle names except the last name which is displayed as it is. For example, if your name is Ram Kumar Sharma, then the output should be R. K. Shrama.
full_name=[]
full_name=input("Enter your full name").split()
for i in full_name[0]:
  print(i,end="")
  break;
print(".",end="")
for i in full_name[1]:
  print(i,end="")
  break;
print(".",end="")
print(full_name[2])
# Out:
# Enter your full nameRam Kumar Sharma
# R.K.Sharma

# %%
#Que-2)Check the occurrence of the letter 'e' and the word 'is' in the sentence "This is umbrella".
sentence="This is umbrella"
count=0;
if 'e' in sentence:
  print("YEs")
else:
  print("No")
# Out:
# YEs

# %%
#Remove items from set1 that are not common to both set1 and set2
set_1={1,2,3,4,5};
set_2={2,3,8,9,10}
set_3=set_1-set_2
set_1=set_1-set_3
set_1
# Out:
# {2, 3}

# %%
#4 Write a program to check if the word 'orange' is present in the "This is orange juice".

# %%
word="This is orange juice";
i=0;
if "orange" in word:
  print("YES")
else:
  print("NO")
# Out:
# YES

# %%
#Write a program to find the length of the string "refrigerator" without using len function.
string="refrigerator"
i=0;
len=0;
for i in string:
  len+=1
print(len)
# Out:
# 12

# %%
#Write a program to print every character of a string entered by user in a new line using loop.
strin=input("Enter a sentence")
for i in strin:
  print(i)
# Out:
# Enter a sentencethis is fun
# t
# h
# i
# s
#
# i
# s
#
# f
# u
# n

# %%
#Add a list of elements to a given set
lst=[6,7,8]
set_1={1,2,3,4,5}
for i in lst:
  set_1.add(i)

# %%
print(set_1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
#Return a new set of identical items from a given two set.
set_1={1,2,3}
set_2={2,3,5}
set_3=set_1-set_2

# %%
set_3=set_1-set_3

# %%
set_3
# Out:
# {2, 3}

# %%
#Returns a new set with all items from both sets by removing duplicates
set_1={1,2,3}
set_2={2,3,5}
set_3=set_1.union(set_2)
set_4=set_1.intersection(set_2)
set_3=set_3-set_4
print(set_3)
# Out:
# {1, 5}

# %%
#Que10)Given two Python sets, update the first set with items that exist only in the first set and not in the second set.

# %%
set_1={1,2,3,4}
set_2={2,3,5,4}
set_3=set_1-set_2
print(set_3)
set_1.update(set_3)
print(set_1)
# Out:
# {1}
# {1, 2, 3, 4}

# %%
#Remove items 10, 20, 30 from the following set at once
set_1 = {10, 20, 30, 40, 50}
set_2={10,20,30}
set_1=set1-set_2
print(set_1)
# Out:
# {40, 50}

# %%
#Return a set of all elements in either A or B, but not both

def disimlar(set_1,set_2):
  set_1=set1-set_2
  return set_1
set_1 = {10, 20, 30, 40, 50}
set_2={10,20,30}
disimlar(set_1,set_2)
# Out:
# {40, 50}

# %%
#Check if two sets have any elements in common. If yes, display the common elements.
set_3 = {10,20, 30,5}
set_4={10,20,30}
set_5=set_3.intersection(set_4)
print(set_5)
# Out:
# {10, 20, 30}

# %%
#Update set1 by adding items from set2, except common items
set_5 = {10,20, 30,5}
set_6={10,20,30}
set_7=set_5.intersection(set_6)
set_5.update(set_7)
print(set_5)
# Out:
# {20, 5, 10, 30}

# %%
#Below are the two lists convert it into the dictionary
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]
dict_1=dict(zip(keys,values))
dict_1['Ten']
# Out:
# 10

# %%
# Merge following two Python dictionaries into one
dict1 = {'Ten': 10, 'Twenty': 20, 'Thirty': 30}
dict2 = {'Thirty': 30, 'Fourty': 40, 'Fifty': 50}
dict1.update(dict2)
print(dict1)
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30, 'Fourty': 40, 'Fifty': 50}

# %%
a=int(input())
b=int(input())
#(a+b)**2=a**2+b**2+2*a*b;
result=(a**2)+(b**2)+(2*a*b);
print(result)
result=(a**2)+(b**2)-(2*a*b);
print(result)
# Out:
# 3
# 4
# 49
# 1

# %%
def diameter(r):
  return 2*r
def surfaceArea(r):
  return (4*3.14)*(r**2)
def volume(r):
  ans=(4/3)*(3.14)*(r**3)
  return ans
def circum(r):
  ans=(2*3.14)*r
  return ans
r=int(input())
print("diameter",diameter(r))
print("surface area",surfaceArea(r))
print("volume",volume(r))
print("circumference",circum(r))

#Diameter
# Out:
# 2
# diameter 4
# surface area 50.24
# volume 33.49333333333333
# circumference 12.56

# %%
# Function to calculate Volume of Cone
def volume(r, h):
    return (1 / 3) * (3.14) * r * r * h
 
# Function To Calculate Surface Area of Cone
def surfacearea(r, s):
    return (3.14) * (3.14) * s + (3.14)* r * r
 
# Driver Code
radius = float(5)
height = float(12)
slat_height = float(13)
print( "Volume Of Cone : ", volume(radius, height) )
print( "Surface Area Of Cone : ", surfacearea(radius, slat_height) )
# Out:
# Volume Of Cone :  314.0
# Surface Area Of Cone :  206.6748

# %%
tup1=(1,2,3)
tup2=(3,4,5)
tup3=tup1+(tup2)
tup3
repeat_tup=tup3*2
print(repeat_tup)

# %%
repeat_tup
# Out:
# (1, 2, 3, 3, 4, 5, 1, 2, 3, 3, 4, 5)

# %%
list=['one','two','three']
for i in list:
  print(id(i))
#so i think id is unique for each element of the lsit
# Out:
# 140014566449584
# 140014566449648
# 140014345415024

# %%
n=int(input())
lst=[]
for i in range(0,n):
  q=int(input())
  lst.append(q)
k=int(input("Enter the element whose occure you want"))
count=0
for i in lst:
  if i==k:
    count=count+1
print("total number of occurences are",count)
# Out:
# 2
# 3
# 3
# Enter the element whose occure you want3
# total number of occurences are 2

# %%
def fun1():
  n=int(input())
  lst=[]
  for i in range(0,n):
    q=float(input())
    lst.append(q)
  print("sum",sum(lst))
  av=sum(lst)/n
  print("Average",av)

# %%
fun1()
# Out:
# 3
# 1.5
# 2
# 3
# sum 6.5
# Average 2.1666666666666665

# %%
def dec2binary(n):
   if n > 1:
       dec2binary(n//2)
   print(n % 2,end = '')
n = int(input("Enter an integer: "))
dec2binary(n)
# Out:
# Enter an integer: 4
# 100

# %%
(4)
# Out:
# 0

# %%
lst
# Out:
# [2]
