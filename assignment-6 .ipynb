# %%
#Q1. Write a Python function to find the Max of three numbers.
def find_max(a,b,c):
  return max(c,max(a,b))
a=int(input())
b=int(input())
c=int(input())
find_max(a,b,c)
# Out:
# 1
# 2
# 5
# 5

# %%
#Q2.Write a Python function to sum all the numbers in a list.
lst=[1,2,3,4,5]
sum=0;
for i in lst:
  sum=sum+i
print(sum)
# Out:
# 15

# %%
#Q3.Write a Python function to reverse a string. 
def rev(str):
  return str[::-1]
str=input()
print(rev(str))
# Out:
# this is good
# doog si siht

# %%
#Q4. Write a Python function to check whether a number falls in a given range.
num=int(input('number'))
start=int(input('starting of range'))
end=int(input('ending of range'))
if(num>=start and num<end):
  print("yes")
else:
  print("NO")
# Out:
# number5
# starting of range6
# ending of range1
# NO

# %%
'''Q5. Write a Python function that takes a list 
and returns a new list with unique elements of the first list.'''
def unique_list(l):
  x = []
  for a in l:
    if a not in x:
      x.append(a)
  return x

print(unique_list([1,2,3,3,3,3,4,5]))
# Out:
# [1, 2, 3, 4, 5]

# %%
#Write a Python function that takes a number as a parameter and check the number is prime or not.  
def test_prime(n):
    if (n==1):
        return False
    elif (n==2):
        return True;
    else:
        for x in range(2,n):
            if(n % x==0):
                return False
        return True             
print(test_prime(9))
# Out:
# False

# %%
#Write a Python function to print the list of even numbers from a given list.
list1 = [11,23,45,23,64,22,11,24]
# iteration
for num in list1:
   # check
   if num % 2 == 0:
      print(num, end = " ")
# Out:
# 64 22 24

# %%
#Q8. Write a Python function that checks whether a passed string is palindrome or not.
def isPalindrome(string):
	left_pos = 0
	right_pos = len(string) - 1
	
	while right_pos >= left_pos:
		if not string[left_pos] == string[right_pos]:
			return False
		left_pos += 1
		right_pos -= 1
	return True
print(isPalindrome('aza'))
# Out:
# True

# %%
#Q9. Write a Python program that accepts a hyphen-separated sequence of words as
 #input and prints the words in a hyphen-separated sequence after sorting them alphabetically
items=[n for n in input().split('-')]
items.sort()
print('-'.join(items))
# Out:
# green-red-yellow-black-white
# black-green-red-white-yellow

# %%
#Write a Python function to create and print a list 
#where the values are square of numbers between 1 and 30 (both included).
def printValues():
	l = list()
	for i in range(1,21):
		l.append(i**2)
	print(l)
		
printValues()
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400]

# %%
#Q11. Write a function calculation() such that it can accept 
#two variables and calculate the addition and subtraction of them.
#And also it must return both addition and 
#subtraction in a single return call.
def calculation(a,b):
  return a+b,a-b
a,b=calculation(2,1);
print(a)
print(b)
# Out:
# 3
# 1

# %%
# Create a function showEmployee() in such a way that it should accept employee name, 
#and its salary and display both.
# If the salary is missing in the function call assign default value 9000 to salary.
def func(employee, salary=9000):
    print('employee: ', employee )
    print('Salary: ', salary)

func('Ram', 3000)
func('Shyam')
# Out:
# employee:  Ram
# Salary:  3000
# employee:  Shyam
# Salary:  9000
